# %% [markdown]
# <img src="Pictures/galaxy.jpg" alt="Galaxy Image" style="width:2050px;height:400px;">

# %% [markdown]
# <h1>Importig Dependencies</h1>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from tensorflow import keras

import cv2
import sklearn
from sklearn.model_selection import train_test_split

from astroNN.datasets import galaxy10
from astroNN.datasets.galaxy10 import galaxy10cls_lookup
# Out:
# WARNING:tensorflow:From C:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# <h1>Galaxy10 Dataset</h1>

# %% [markdown]
# <div class="alert alert-info" style="color:black;">
# <b>
#     The galaxy10 dataset is a dataset that contains 21785 256x256 pixels colored galaxy images with 10 different classes. The images from this dataset come from Sloan Digital Sky Survey and the labels come from Galaxy Zoo. Each of the images within the dataset is classified under one of the 10 classes.
# </b>
# </div>
# iv>
# iv>

# %%
images, labels = galaxy10.load_data()
# Out:
# C:\Users\dell\.astroNN\datasets\Galaxy10_DECals.h5 was found!

# %% [markdown]
# <h3>Dataset's size</h3>

# %%
images.shape
# Out:
# (17736, 256, 256, 3)

# %% [markdown]
# <h3>Displaying some images</h3>

# %%
features = ['Disk, Face-on, No Spiral', 'Smooth, Completely round', 'Smooth, in-between round', 'Smooth, Cigar shaped', 'Disk, Edge-on, Rounded Bulge', 'Disk, Edge-on, Boxy Bulge', 
            'Disk, Edge-on, No Bulge','Disk, Face-on, Tight Spiral', 'Disk, Face-on, Medium Spiral', 'Disk, Face-on, Loose Spiral']
fig = plt.figure(figsize=(20,20)) 

for i in range(15):
    plt.subplot(5,5,i+1)    
    plt.imshow(images[i])
    plt.title(features[labels[i]])
    fig.tight_layout(pad=3.0)
    
plt.show()

# %% [markdown]
# <h3>Classes distribution</h3>

# %%
df = pd.DataFrame(data=labels)

counts = df.value_counts().sort_index()
print(counts)
# Out:
# 0    1081
# 1    1853
# 2    2645
# 3    2027
# 4     334
# 5    2043
# 6    1829
# 7    2628
# 8    1423
# 9    1873
# Name: count, dtype: int64

# %%
def class_distribution(x, y, labels):
    fig, ax = plt.subplots()
    ax.bar(x, y)
    ax.set_xticklabels(labels, rotation=90)
    plt.show()
    
class_distribution(features, counts, features)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6284\139427031.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %% [markdown]
# <div class="alert alert-danger" style="color:black;">
# <b>
#     Alert: The dataset is imbalanced!
# </b>
# </div>
